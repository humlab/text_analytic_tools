# %% [markdown]
# # Papal text analysis
# A scratchbook on the work done with the text scraped from the vatical web site.

# %% [markdown]
# ## Named entity recognition (NER)
# The Stanford NER tagger has been used to tag the text, with the 3-class model english.all.3class.distsim.crf.ser, which recognizes LOCATION, PERSON and ORGANIZATION. This model has been trained on the CoNLL 2003, MUC 6 and MUC 7 data sets (and some additional data as stated in [https://nlp.stanford.edu/software/CRF-NER.shtml].
#
# Stanford NER tagger citation/reference:
# ```
# Jenny Rose Finkel, Trond Grenager, and Christopher Manning. 2005. Incorporating Non-local Information into Information Extraction Systems by Gibbs Sampling. Proceedings of the 43nd Annual Meeting of the Association for Computational Linguistics (ACL 2005), pp. 363-370. http://nlp.stanford.edu/~manning/papers/gibbscrf3.pdf
# ```
# The tagging of the Vatican text is done with a short Python script that uses the `nltk.tag.StanfordNERTagger` wrapper around the  Stanford tagger (which is written in Java).  The script processes each file in these steps:
#
# * Read the text and split it into a sequence of words
# * Ask the NER tagger to tag the sequence of words
# * Extract the entities tagged as LOCATION, PERSON or ORGANIZATION. Merge consequtive entities of the same class into a *phrase*.
# * count number of occurrences of each word (or phrase)
# * write result to file, one line for each combination word and class, and with word count together with fields specifying the pope, type of document, year and name of dokument.

# %% [markdown]
# ### How to train a new model

# %% [markdown]
# The used model, english.all.3class.distsim.crf.ser, has some shortcomings though, when it comes to recognizing religious entities. To improve the result you can either train a new model or assign classes to the unrecognized by hand.
#
# Instructions on how to train a new model can be found at [http://nlp.stanford.edu/software/crf-faq.shtml#b]. There are some constraints, though, the important being that it's not possible to extend an existing model. The data used to create Stanford's official models is also not available. A new model must hence be created from scratch, but some of the tagged datasets found at [http://www.cs.technion.ac.il/~gabr/resources/data/ne_datasets.html] can be used as a starting point.
#
# 1. Select some existing tagged dataset (if exists)
# 2. Find resources that can enable automatic class assignments (gazetteers for names, locations and organizations)
# 3. Create additional tagged datasets that includes the additional proper nouns you wish to train
#     1. Select and create a big enough corpus that include targeted proper nouns (assuming named entity recognition)
#     2. Split the corpus into smaller documents
#     3. Tokenize the corpus using the PTBTokenizer:
# > java -cp stanford-ner.jar edu.stanford.nlp.process.PTBTokenizer corpus.txt > corpus.tok
#     4. Annotate the corpus using gazetteers automatically as well as manually.
#
# The tagged datasets must be transformed into to a tab-separated file with the format that Stanford NER accepts. As stated in the docs, the parser is not very forgiving. The word and class must be seperated by a single tab, and there cannot be any extra spaces etc.
#
# 4. Create a *properties file* that specifies the options to be used in the training. (The properties can also be entered as command line options.) a sample properties file file can be found at [https://nlp.stanford.edu/software/crf-faq.shtml#b]:
#
# > ```
# > trainFile = your-trainded-corpus-file.tsv
# > serializeTo = your-ner-model.ser.gz
# > map = word=0,answer=1
# > maxLeft=1
# > useClassFeature=true
# > useWord=true
# > useNGrams=true
# > noMidNGrams=true
# > maxNGramLeng=6
# > usePrev=true
# > useNext=true
# > useDisjunctive=true
# > useSequences=true
# > usePrevSequences=true
# > useTypeSeqs=true
# > useTypeSeqs2=true
# > useTypeySequences=true
# > wordShape=chris2useLC
# > ```
#
# 5. Next step is to actually create the new model:
#
# > java -cp stanford-ner.jar edu.stanford.nlp.ie.crf.CRFClassifier -prop corpus.prop

# %% [markdown]
# ## Compute co-occurrence of NER entities
#
# This section computes word-word co-occurrences for the Vatican text material. Two words are co-occurring if they exist in the same document. The co-occurence are computed as the product of the number of times the two words occur in the same document.
# ### Import the Excel file
# Load the he NER data computed by `NER_runner.py` into a Panda DataFrame. Note that `pandas` (and dependencies) and the `xldr` packaged must be installed for this to work.

# %%
import pandas as pd

df = pd.read_excel('../data/NER-john-paul-ii/john-paul-ii.xlsx', 'Sheet1')

# %% [markdown]
# List some columns for the first few records from the loaded data. Note that count is the number of occurrences for the entity in the document (i.e. a word-document co-occurrence).

# %%
df
# Out:
#                                                Document  Year    Genre  \
# 0     john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 1     john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 2     john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 3     john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 4     john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 5     john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 6     john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 7     john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 8     john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 9     john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 10    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 11    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 12    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 13    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 14    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 15    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 16    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 17    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 18    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 19    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 20    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 21    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 22    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 23    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 24    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 25    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 26    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 27    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 28    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# 29    john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  1978  angelus
# ...                                                 ...   ...      ...
# 7257  john-paul-ii_en_angelus_2005_hf-jp-ii-ang-2005...  2005  angelus
# 7258  john-paul-ii_en_angelus_2005_hf-jp-ii-ang-2005...  2005  angelus
# 7259  john-paul-ii_en_angelus_2005_hf-jp-ii-ang-2005...  2005  angelus
# 7260  john-paul-ii_en_angelus_2005_hf-jp-ii-ang-2005...  2005  angelus
# 7261  john-paul-ii_en_angelus_2005_hf-jp-ii-ang-2005...  2005  angelus
# 7262  john-paul-ii_en_angelus_2005_hf-jp-ii-ang-2005...  2005  angelus
# 7263  john-paul-ii_en_angelus_2005_hf-jp-ii-ang-2005...  2005  angelus
# 7264  john-paul-ii_en_angelus_2005_hf-jp-ii-ang-2005...  2005  angelus
# 7265  john-paul-ii_en_angelus_2005_hf-jp-ii-ang-2005...  2005  angelus
# 7266  john-paul-ii_en_angelus_2005_hf-jp-ii-ang-2005...  2005  angelus
# 7267  john-paul-ii_en_angelus_2005_hf-jp-ii-ang-2005...  2005  angelus
# 7268  john-paul-ii_en_angelus_2005_hf-jp-ii-ang-2005...  2005  angelus
# 7269  john-paul-ii_en_angelus_2005_hf-jp-ii-ang-2005...  2005  angelus
# 7270  john-paul-ii_en_angelus_2005_hf-jp-ii-ang-2005...  2005  angelus
# 7271  john-paul-ii_en_angelus_2005_hf-jp-ii-ang-2005...  2005  angelus
# 7272  john-paul-ii_en_angelus_2005_hf-jp-ii-ang-2005...  2005  angelus
# 7273  john-paul-ii_en_angelus_2005_hf-jp-ii-reg-2005...  2005  angelus
# 7274  john-paul-ii_en_angelus_2005_hf-jp-ii-reg-2005...  2005  angelus
# 7275  john-paul-ii_en_angelus_2005_hf-jp-ii-reg-2005...  2005  angelus
# 7276  john-paul-ii_en_angelus_2005_hf-jp-ii-reg-2005...  2005  angelus
# 7277  john-paul-ii_en_angelus_2005_hf-jp-ii-reg-2005...  2005  angelus
# 7278  john-paul-ii_en_angelus_2005_hf-jp-ii-reg-2005...  2005  angelus
# 7279  john-paul-ii_en_angelus_2005_hf-jp-ii-reg-2005...  2005  angelus
# 7280  john-paul-ii_en_angelus_2005_hf-jp-ii-reg-2005...  2005  angelus
# 7281  john-paul-ii_en_angelus_2005_hf-jp-ii-reg-2005...  2005  angelus
# 7282  john-paul-ii_en_angelus_2005_hf-jp-ii-reg-2005...  2005  angelus
# 7283  john-paul-ii_en_angelus_2005_hf-jp-ii-reg-2005...  2005  angelus
# 7284  john-paul-ii_en_angelus_2005_hf-jp-ii-reg-2005...  2005  angelus
# 7285  john-paul-ii_en_angelus_2005_hf-jp-ii-reg-2005...  2005  angelus
# 7286  john-paul-ii_en_angelus_2005_hf-jp-ii-reg-2005...  2005  angelus
#
#               Pope                      Entity    Classifier  Count
# 0     john-paul-ii                      Church  ORGANIZATION      2
# 1     john-paul-ii               Mother of God        PERSON      1
# 2     john-paul-ii                   Elizabeth        PERSON      1
# 3     john-paul-ii               Dear Brothers  ORGANIZATION      1
# 4     john-paul-ii                Jesus Christ        PERSON      1
# 5     john-paul-ii                      Christ        PERSON      1
# 6     john-paul-ii            Vatican Basilica      LOCATION      1
# 7     john-paul-ii                        Pope        PERSON      1
# 8     john-paul-ii                       Jesus        PERSON      1
# 9     john-paul-ii                 Virgin Mary        PERSON      1
# 10    john-paul-ii                  John XXIII        PERSON      2
# 11    john-paul-ii                   John Paul        PERSON      1
# 12    john-paul-ii                  All Saints  ORGANIZATION      3
# 13    john-paul-ii                      Christ        PERSON      2
# 14    john-paul-ii                    St Peter        PERSON      1
# 15    john-paul-ii                      Poland      LOCATION      2
# 16    john-paul-ii                      Assisi      LOCATION      1
# 17    john-paul-ii                  St Francis      LOCATION      1
# 18    john-paul-ii                       Peter        PERSON      3
# 19    john-paul-ii   Santa Maria sopra Minerva      LOCATION      1
# 20    john-paul-ii               Patron Saints  ORGANIZATION      3
# 21    john-paul-ii                      Bishop        PERSON      1
# 22    john-paul-ii                      Christ        PERSON      1
# 23    john-paul-ii                John Paul II        PERSON      2
# 24    john-paul-ii                        Pope        PERSON      1
# 25    john-paul-ii                   Jerusalem      LOCATION      1
# 26    john-paul-ii                       Italy      LOCATION      6
# 27    john-paul-ii                      Krakow      LOCATION      1
# 28    john-paul-ii                        Rome      LOCATION     11
# 29    john-paul-ii                       Siena      LOCATION      2
# ...            ...                         ...           ...    ...
# 7257  john-paul-ii                      Christ        PERSON      1
# 7258  john-paul-ii          St Peter 's Square      LOCATION      2
# 7259  john-paul-ii             Leonardo Sandri        PERSON      1
# 7260  john-paul-ii                      Europe      LOCATION      1
# 7261  john-paul-ii                   Holy Magi  ORGANIZATION      1
# 7262  john-paul-ii             Cross of Christ  ORGANIZATION      1
# 7263  john-paul-ii                       Cross  ORGANIZATION      1
# 7264  john-paul-ii                      Christ        PERSON      1
# 7265  john-paul-ii                       Jesus        PERSON      1
# 7266  john-paul-ii          St Peter 's Square      LOCATION      1
# 7267  john-paul-ii                     Cologne      LOCATION      1
# 7268  john-paul-ii                     Germany      LOCATION      1
# 7269  john-paul-ii                        East      LOCATION      1
# 7270  john-paul-ii                        Rome      LOCATION      2
# 7271  john-paul-ii                      Square      LOCATION      1
# 7272  john-paul-ii               Camillo Ruini        PERSON      2
# 7273  john-paul-ii             Leonardo Sandri        PERSON      1
# 7274  john-paul-ii  Libreria Editrice Vaticana        PERSON      1
# 7275  john-paul-ii                Regina Caeli        PERSON      1
# 7276  john-paul-ii                      Sandri        PERSON      1
# 7277  john-paul-ii                John Paul II        PERSON      2
# 7278  john-paul-ii                       Jesus        PERSON      1
# 7279  john-paul-ii          St Peter 's Square      LOCATION      1
# 7280  john-paul-ii                        Pope        PERSON      1
# 7281  john-paul-ii                      Virgin        PERSON      1
# 7282  john-paul-ii                        John        PERSON      1
# 7283  john-paul-ii                        Rome      LOCATION      1
# 7284  john-paul-ii                        Mary        PERSON      1
# 7285  john-paul-ii                      Thomas        PERSON      1
# 7286  john-paul-ii        Secretariat of State  ORGANIZATION      1
#
# [7287 rows x 7 columns]

# %%
df[['Document', 'Entity', 'Classifier', 'Count']].head()
# Out:
#                                             Document         Entity  \
# 0  john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...         Church
# 1  john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  Mother of God
# 2  john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...      Elizabeth
# 3  john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...  Dear Brothers
# 4  john-paul-ii_en_angelus_1978_hf-jp-ii-ang-1978...   Jesus Christ
#
#      Classifier  Count
# 0  ORGANIZATION      2
# 1        PERSON      1
# 2        PERSON      1
# 3  ORGANIZATION      1
# 4        PERSON      1

# %% [markdown]
# What we want is to compute *word-word* co-occurrence matrix within the same document. To do this we first join all the records from the same document with eachother. This will produce a cartesian product of all possible entity-pairs in the same document. The result grouped by document and entity pairs (n.b. this step is actually not necessary since the data is already grouped by document and entity).

# %%
df2 = (pd.merge(df, df, on='Document')).query('Entity_x < Entity_y')\
        .groupby(['Document', 'Entity_x', 'Classifier_x', 'Entity_y', 'Classifier_y', 'Year_x', 'Genre_x' ])\
            [['Count_x', 'Count_y']].sum()

# %% [markdown]
# Let's compute the co-occurrence value as the product of the number of times each entity occurs in the document. Add the value as a new column in the dataframe. (The word counts are removed to prevent them to be written to file.)

# %%
df2['Count'] = df2['Count_x'] * df2['Count_y']
df2.pop('Count_x')
df2.pop('Count_y')

df2.head(10)
# Out:
#                                                                                                                        Count
# Document                                           Entity_x Classifier_x Entity_y         Classifier_y Year_x Genre_x
# john-paul-ii_en_angelus_1978_hf-jp-ii-ang-19781029 Christ   PERSON       Church           ORGANIZATION 1978   angelus      2
#                                                                          Dear Brothers    ORGANIZATION 1978   angelus      1
#                                                                          Elizabeth        PERSON       1978   angelus      1
#                                                                          Jesus            PERSON       1978   angelus      1
#                                                                          Jesus Christ     PERSON       1978   angelus      1
#                                                                          John Paul        PERSON       1978   angelus      1
#                                                                          John XXIII       PERSON       1978   angelus      2
#                                                                          Mother of God    PERSON       1978   angelus      1
#                                                                          Pope             PERSON       1978   angelus      1
#                                                                          Vatican Basilica LOCATION     1978   angelus      1

# %% [markdown]
# Write the result to a text file:

# %%
df2.to_csv('../data/NER-john-paul-ii/john-paul-ii-co-occurrence.csv',  sep=';')
